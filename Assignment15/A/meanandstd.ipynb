# %% [markdown]
# <a href="https://colab.research.google.com/github/roshantac/EVA4/blob/master/Assignment15/A/meanandstd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 13586502395692226715, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 1865388795407429857
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 6065368926541524677
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 7304675328
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 17746884093907609487
#  physical_device_desc: "device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1"]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
mkdir Test

# %%
# !cp '/content/drive/My Drive/DatasetFinal.zip' '/content/Test/'

# %%
import os

list = os.listdir('/content/Test/Data/Output/fgbgmask') # dir is your directory path
number_files = len(list)
print (number_files)
# Out:
# 408040

# %%
destDataDir = 'Test/'
path_to_zip_file = 'Test/DatasetFinal.zip'
import zipfile
with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall(destDataDir)

# %%
cd Test/content/Test/Data/Dataset/
# Out:
# /content/Test/content/Test/Data/Dataset

# %%
import os
fp = open("data3.txt",'w')
for idx, d in enumerate(os.listdir('/content/Test/content/Test/Data/Dataset/DepthMap/')):
  print (d, file=fp)
fp.close()

# %%
# !cp 'data3.txt' '/content/drive/My Drive/'

# %%
ls
# Out:
# data3.txt  DepthMap/  fgbg/  fgbgmask/

# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

srcDir = '/content/Test/content/Test/Data/Dataset/fgbg/'
dstDir = '/content/Test/fgbg/'
fp = open('/content/drive/My Drive/data3.txt')
s=fp.read().splitlines()
for i in s:
  print(i)
  src = str(srcDir+i)
  print(src)
  img = cv2.imread(src)
  cv2.imwrite(dstDir+i, cv2.resize(img, (200,200), interpolation = cv2.INTER_AREA),[int(cv2.IMWRITE_JPEG_QUALITY), 25])
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/Test/content/Test/Data/Dataset/fgbg/img22523.jpg
# img31939.jpg
# /content/Test/content/Test/Data/Dataset/fgbg/img31939.jpg
# img215323.jpg
# /content/Test/content/Test/Data/Dataset/fgbg/img215323.jpg
# img118893.jpg
# /content/Test/content/Test/Data/Dataset/fgbg/img118893.jpg
# img194527.jpg
# /content/Test/content/Test/Data/Dataset/fgbg/img194527.jpg
# img223776.jpg
# /content/Test/content/Test/Data/Dataset/fgbg/img223776.jpg
# img396336.jpg
# /content/Test/content/Test/Data/Dataset/fgbg/img396336.jpg
# img9331.jpg
# /content/Test/content/Test/Data/Dataset/fgbg/img9331.jpg
# img166774.jpg
# /content/Test/content/Test/Data/Dataset/fgbg/img166774.jpg
# img122397.jpg
# /content/Test/content/Test/Data/Dataset/fgbg/img122397.jpg
# img382967.jpg
# /content/Test/content/Test/Data/Dataset/fgbg/img382967.jpg
# img385713.jpg
# /content/Test/content/Test/Data/Dataset/fgbg/img385713.jpg
# img160146.jpg
# ...

# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

srcDir = '/content/Test/content/Test/Data/Dataset/fgbgmask/'
dstDir = '/content/Test/fgbgmask/'
fp = open('/content/drive/My Drive/data3.txt')
s=fp.read().splitlines()
for i in s:
  print(i)
  a= 'mask'+i[3:]
  src = str(srcDir+a)
  print(src)
  img = cv2.imread(src,0)
  cv2.imwrite(dstDir+i, cv2.resize(img, (200,200), interpolation = cv2.INTER_AREA),[int(cv2.IMWRITE_JPEG_QUALITY), 25])
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/Test/content/Test/Data/Dataset/fgbgmask/mask26640.jpg
# img64676.jpg
# /content/Test/content/Test/Data/Dataset/fgbgmask/mask64676.jpg
# img288121.jpg
# /content/Test/content/Test/Data/Dataset/fgbgmask/mask288121.jpg
# img238507.jpg
# /content/Test/content/Test/Data/Dataset/fgbgmask/mask238507.jpg
# img280623.jpg
# /content/Test/content/Test/Data/Dataset/fgbgmask/mask280623.jpg
# img160273.jpg
# /content/Test/content/Test/Data/Dataset/fgbgmask/mask160273.jpg
# img108752.jpg
# /content/Test/content/Test/Data/Dataset/fgbgmask/mask108752.jpg
# img114649.jpg
# /content/Test/content/Test/Data/Dataset/fgbgmask/mask114649.jpg
# img164602.jpg
# /content/Test/content/Test/Data/Dataset/fgbgmask/mask164602.jpg
# img347772.jpg
# /content/Test/content/Test/Data/Dataset/fgbgmask/mask347772.jpg
# img399202.jpg
# /content/Test/content/Test/Data/Dataset/fgbgmask/mask399202.jpg
# img162609.jpg
# ...

# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

srcDir = '/content/Test/content/Test/Data/Dataset/DepthMap/'
dstDir = '/content/Test/Depthmap/'
fp = open('/content/drive/My Drive/data3.txt')
s=fp.read().splitlines()
for i in s:
  print(i)
  src = str(srcDir+i)
  print(src)
  img = cv2.imread(src,0)
  cv2.imwrite(dstDir+i, cv2.resize(img, (200,200), interpolation = cv2.INTER_AREA),[int(cv2.IMWRITE_JPEG_QUALITY), 25])

# %%
import os
import numpy as np
import cv2
CHANNEL_NUM = 3
def cal_dir_stat(root):
    pixel_num = 0 # store all pixel number in the dataset
    channel_sum = np.zeros(CHANNEL_NUM)
    channel_sum_squared = np.zeros(CHANNEL_NUM)
    import os

    for idx, d in enumerate( os.listdir(root)):
        im_pths = root+d
        im = cv2.imread(im_pths) # image in M*N*CHANNEL_NUM shape, channel in BGR order
        im = im/255.0
        pixel_num += (im.size/CHANNEL_NUM)
        channel_sum += np.sum(im, axis=(0, 1))
        channel_sum_squared += np.sum(np.square(im), axis=(0, 1))
        print(idx)

    bgr_mean = channel_sum / pixel_num
    bgr_std = np.sqrt(channel_sum_squared / pixel_num - np.square(bgr_mean))
    
    # change the format from bgr to rgb
    rgb_mean = list(bgr_mean)[::-1]
    rgb_std = list(bgr_std)[::-1]
    
    return rgb_mean, rgb_std
mean, std = cal_dir_stat("/content/Test/fgbg/")
print("mean:",mean, "std:",std)

# %%
import os
import numpy as np
import cv2
CHANNEL_NUM = 1
def cal_dir_stat(root):
    pixel_num = 0 # store all pixel number in the dataset
    channel_sum = np.zeros(CHANNEL_NUM)
    channel_sum_squared = np.zeros(CHANNEL_NUM)
    import os

    for idx, d in enumerate( os.listdir(root)):
        im_pths = root+d
        im = cv2.imread(im_pths,0) # image in M*N*CHANNEL_NUM shape, channel in BGR order
        im = im/255.0
        pixel_num += (im.size/CHANNEL_NUM)
        channel_sum += np.sum(im, axis=(0, 1))
        channel_sum_squared += np.sum(np.square(im), axis=(0, 1))
        print(idx)

    bgr_mean = channel_sum / pixel_num
    bgr_std = np.sqrt(channel_sum_squared / pixel_num - np.square(bgr_mean))
    
    # change the format from bgr to rgb
    rgb_mean = list(bgr_mean)[::-1]
    rgb_std = list(bgr_std)[::-1]
    
    return rgb_mean, rgb_std
mean, std = cal_dir_stat("/content/Test/fgbgmask/")
print("mean:",mean, "std:",std)

# %%
import os
import numpy as np
import cv2
CHANNEL_NUM = 1
def cal_dir_stat(root):
    pixel_num = 0 # store all pixel number in the dataset
    channel_sum = np.zeros(CHANNEL_NUM)
    channel_sum_squared = np.zeros(CHANNEL_NUM)
    import os

    for idx, d in enumerate( os.listdir(root)):
        im_pths = root+d
        im = cv2.imread(im_pths,0) # image in M*N*CHANNEL_NUM shape, channel in BGR order
        im = im/255.0
        pixel_num += (im.size/CHANNEL_NUM)
        channel_sum += np.sum(im, axis=(0, 1))
        channel_sum_squared += np.sum(np.square(im), axis=(0, 1))
        print(idx)

    bgr_mean = channel_sum / pixel_num
    bgr_std = np.sqrt(channel_sum_squared / pixel_num - np.square(bgr_mean))
    
    # change the format from bgr to rgb
    rgb_mean = list(bgr_mean)[::-1]
    rgb_std = list(bgr_std)[::-1]
    
    return rgb_mean, rgb_std
mean, std = cal_dir_stat("/content/Test/Depthmap/")
print("mean:",mean, "std:",std)

# %%
ls
# Out:
# data3.txt  DepthMap/  fgbg/  fgbgmask/
